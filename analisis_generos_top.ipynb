# %%
from config import get_db_connection, pd, plt, sns, MaxNLocator
conn = get_db_connection()

# %%
sql_generos_mas_leidos = """
SELECT * FROM Generos_mas_leidos;
"""

# %%
df_generos_mas_leidos = pd.read_sql_query(sql_generos_mas_leidos, conn)

# %%
plt.style.use('dark_background')
plt.figure(figsize=(8, 5))
sns.barplot(x='genero', y='total_lecturas', data=df_generos_mas_leidos, palette='plasma')
plt.title('Géneros Más Leídos (Conteo Total)')
plt.xlabel('Género')
plt.ylabel('Número de Préstamos')
plt.show()
# Out:
# C:\Users\galo\AppData\Local\Temp\ipykernel_18864\2755764632.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='genero', y='total_lecturas', data=df_generos_mas_leidos, palette='plasma')
